# %%
import os

import torch
import numpy as np

from model import model_MAF
from model.modules import data_preprocessing
from model.modules import dataset_supercell as dataset
from model.modules import loader
from model.modules import utils
from model.modules import visualizations

import matplotlib.pyplot as plt
import matplotlib.colors
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker as tick
from matplotlib import cm

plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize']=20
plt.rcParams['ytick.labelsize']=20
plt.rcParams['lines.linewidth']=6
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)

# %%
timesteps = ['10000', '10100', '10200', '10300', '10400', '10500', '10600', '10700', '10800', '10900', '11000']

# %%
supercells = ['/bigdata/hplsim/aipp/Anna/lwfa_2cells_prevm/'+nextfile for nextfile in os.listdir('/bigdata/hplsim/aipp/Anna/lwfa_2cells_prevm')]
datasets = []
models = []

for ind in range(len(supercells)):
    datasets.append(dataset.PCDataset(item_phase_space=supercells[ind],
                                   normalize=True, a=0., b=1.))
    models.append(model_MAF.PC_MAF(dim_condition=2,
                               dim_input=9,
                               num_coupling_layers=3,
                               hidden_size=64,
                               device='cpu',
                               enable_wandb=False,
                               weight_particles=True))

# %%
optimizers = []
test_pointclouds = []
for ind in range(len(supercells)):
    optimizers.append(torch.optim.Adam(models[ind].model.parameters(), lr=1e-3,
                             betas=(0.8, 0.9), eps=1e-6, weight_decay=2e-5))
    test_pointclouds.append(supercells[ind])
    
test_radiation = "/home/willma32/insitu_particles/InSituML/main/ModelHelpers/cINN/rad_test.npy"
log_plots = visualizations.log_one_plot

# %%
import time

for ind in range(len(supercells)):
    print('Train: ', supercells[ind].split('/')[-1].split('.')[0])
    #models[ind].device = 'cuda'
    #models[ind].to('cuda')
    #s = time.time()
    models[ind].train_(datasets[ind],
                   datasets[ind],
                   optimizers[ind],
                   epochs=1001,
                   batch_size=10000,
                   test_epoch=1000,
                   test_pointcloud=test_pointclouds[ind], test_radiation=test_radiation, log_plots=None,
                   path_to_models='/bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_'+supercells[ind].split('/')[-1].split('.')[0]+'/')
    #e = time.time()
    #print('time on cuda, MAF training: ', e-s, 's')
    #break
# Out:
# Train:  10700_42_1152_52
# Total number of points:  493
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1152_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1152_52/
# Train:  10700_43_1151_49
# Total number of points:  465
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1151_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1151_49/
# Train:  10700_42_1149_50
# Total number of points:  568
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1149_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1149_50/
# Train:  10700_43_1150_51
# Total number of points:  438
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1150_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1150_51/
# Train:  10700_45_1149_49
# Total number of points:  599
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1149_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1149_49/
# Train:  10700_45_1151_52
# Total number of points:  578
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1151_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1151_52/
# Train:  10700_44_1151_51
# Total number of points:  530
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1151_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1151_51/
# Train:  10700_44_1149_52
# Total number of points:  554
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1149_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1149_52/
# Train:  10700_43_1152_50
# Total number of points:  470
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1152_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1152_50/
# Train:  10700_42_1152_51
# Total number of points:  580
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1152_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1152_51/
# Train:  10700_42_1150_51
# Total number of points:  579
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1150_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1150_51/
# Train:  10700_43_1149_50
# Total number of points:  519
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1149_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1149_50/
# Train:  10700_43_1151_51
# Total number of points:  446
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1151_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1151_51/
# Train:  10700_44_1149_50
# Total number of points:  543
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1149_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1149_50/
# Train:  10700_42_1151_52
# Total number of points:  484
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1151_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1151_52/
# Train:  10700_42_1150_50
# Total number of points:  578
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1150_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1150_50/
# Train:  10700_45_1151_50
# Total number of points:  568
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1151_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1151_50/
# Train:  10700_44_1151_52
# Total number of points:  480
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1151_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1151_52/
# Train:  10700_44_1149_49
# Total number of points:  480
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1149_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1149_49/
# Train:  10700_44_1150_50
# Total number of points:  520
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1150_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1150_50/
# Train:  10700_44_1149_51
# Total number of points:  554
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1149_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1149_51/
# Train:  10700_43_1150_52
# Total number of points:  446
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1150_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1150_52/
# Train:  10700_42_1150_52
# Total number of points:  532
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1150_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1150_52/
# Train:  10700_43_1151_52
# Total number of points:  412
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1151_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1151_52/
# Train:  10700_43_1150_50
# Total number of points:  529
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1150_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1150_50/
# Train:  10700_45_1150_51
# Total number of points:  562
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1150_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1150_51/
# Train:  10700_42_1149_49
# Total number of points:  526
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1149_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1149_49/
# Train:  10700_45_1152_52
# Total number of points:  553
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1152_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1152_52/
# Train:  10700_42_1152_49
# Total number of points:  510
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1152_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1152_49/
# Train:  10700_45_1151_49
# Total number of points:  544
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1151_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1151_49/
# Train:  10700_43_1152_52
# Total number of points:  383
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1152_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1152_52/
# Train:  10700_45_1150_49
# Total number of points:  606
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1150_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1150_49/
# Train:  10700_42_1151_51
# Total number of points:  558
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1151_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1151_51/
# Train:  10700_45_1152_50
# Total number of points:  538
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1152_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1152_50/
# Train:  10700_43_1152_51
# Total number of points:  455
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1152_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1152_51/
# Train:  10700_42_1150_49
# Total number of points:  445
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1150_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1150_49/
# Train:  10700_45_1149_52
# Total number of points:  562
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1149_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1149_52/
# Train:  10700_44_1151_49
# Total number of points:  491
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1151_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1151_49/
# Train:  10700_43_1151_50
# Total number of points:  491
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1151_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1151_50/
# Train:  10700_42_1152_50
# Total number of points:  518
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1152_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1152_50/
# Train:  10700_45_1151_51
# Total number of points:  555
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1151_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1151_51/
# Train:  10700_43_1149_49
# Total number of points:  505
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1149_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1149_49/
# Train:  10700_42_1149_51
# Total number of points:  571
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1149_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1149_51/
# Train:  10700_45_1152_49
# Total number of points:  564
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1152_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1152_49/
# Train:  10700_44_1151_50
# Total number of points:  537
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1151_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1151_50/
# Train:  10700_45_1150_52
# Total number of points:  569
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1150_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1150_52/
# Train:  10700_42_1149_52
# Total number of points:  578
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1149_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1149_52/
# Train:  10700_44_1152_51
# Total number of points:  500
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1152_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1152_51/
# Train:  10700_43_1149_51
# Total number of points:  466
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1149_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1149_51/
# Train:  10700_44_1150_52
# Total number of points:  495
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1150_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1150_52/
# Train:  10700_43_1149_52
# Total number of points:  463
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1149_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1149_52/
# Train:  10700_43_1150_49
# Total number of points:  488
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1150_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1150_49/
# Train:  10700_44_1152_50
# Total number of points:  508
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1152_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1152_50/
# Train:  10700_44_1152_49
# Total number of points:  481
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1152_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1152_49/
# Train:  10700_44_1150_49
# Total number of points:  470
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1150_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1150_49/
# Train:  10700_44_1152_52
# Total number of points:  488
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1152_52/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1152_52/
# Train:  10700_45_1149_50
# Total number of points:  586
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1149_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1149_50/
# Train:  10700_45_1152_51
# Total number of points:  539
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1152_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1152_51/
# Train:  10700_42_1151_49
# Total number of points:  486
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1151_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1151_49/
# Train:  10700_45_1150_50
# Total number of points:  567
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1150_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1150_50/
# Train:  10700_43_1152_49
# Total number of points:  465
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1152_49/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_43_1152_49/
# Train:  10700_42_1151_50
# Total number of points:  573
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1151_50/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_42_1151_50/
# Train:  10700_44_1150_51
# Total number of points:  569
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1150_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_44_1150_51/
# Train:  10700_45_1149_51
# Total number of points:  574
# Size of loader:  1
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1149_51/
# Save model to /bigdata/hplsim/aipp/Anna/lwfa_tests1/models/RESModels_10700_45_1149_51/

# %%
param_size = 0
for param in models[0].model.parameters():
    param_size += param.nelement() * param.element_size()
buffer_size = 0
for buffer in models[0].model.buffers():
    buffer_size += buffer.nelement() * buffer.element_size()

size_all_mb = (param_size + buffer_size) / 1024**2
print('model size: {:.3f}MB'.format(size_all_mb))
# Out:
# model size: 0.433MB

# %%
supercells_tensors = []
file_sizes = []
for ind in range(len(supercells)):
    t = np.loadtxt(supercells[ind])
    file_sizes.append(t.shape[0])
    supercells_tensors.append(t)
all_cells = np.concatenate([arr for arr in supercells_tensors], axis=0)
print(all_cells.shape)
# Out:
# (33284, 9)

# %%
#supercell = [int(k) for k in test_pointcloud.split('/')[-1].split('.')[0].split('_')[1:]]
iteration = '10700'
pointcloud_tensor = all_cells

num_particles = 33284
idx = np.random.randint(pointcloud_tensor.shape[0], size=num_particles)
pointcloud_tensor = pointcloud_tensor[idx, :]
radiation_tensor = torch.Tensor([0.5,0.5]).float().repeat(pointcloud_tensor.shape[0], 1)

labels_x = ['x', 'y', 'z', 'x', 'y', 'z']
labels_y = ['xp', 'yp', 'zp', 'xpp', 'ypp', 'zpp']

pred_pointclouds = []
for ind in range(len(supercells)):
    radiation_tensor = torch.Tensor([0.5,0.5]).float().repeat(file_sizes[ind], 1)
    pred_pointclouds.append((models[ind].sample_pointcloud(radiation_tensor.to(models[ind].device), radiation_tensor.shape[0])).detach().cpu().numpy())

pred_pointcloud = np.concatenate([arr for arr in pred_pointclouds], axis=0)
print(pred_pointcloud.shape)
#pred_pointcloud = pred_pointcloud_full.detach().cpu().numpy()
# Out:
# (33284, 9)

# %%
def plot_hist(pc, pc_pred, axs, comp_x, label_x):
    axs.hist(pc[:,comp_x], density=True, bins=30, label='Groundtruth', alpha = 0.4)  # density=False would make counts
    axs.hist(pc_pred[:,comp_x], density=True, bins=30, label='Reconstruction', alpha = 0.4)  # density=False would make counts
    axs.set_ylabel('Probability')
    axs.set_xlabel(label_x)
    axs.grid(True)
    axs.legend(fontsize=18)

def plot_2D_GTandRec(pc, pc_pred, comp_x, comp_y, axs, label_x, label_y):
    axs.scatter(pc[:,comp_x], pc[:,comp_y], s=30, alpha=0.75, label='Groundtruth')
    if pc_pred is not None:
        axs.scatter(pc_pred[:,comp_x], pc_pred[:,comp_y], s=30, alpha=0.2, label='Prediction')
    axs.tick_params(axis='y', which='major', rotation=45)
    axs.grid(True)
    axs.set_xlabel(label_x)
    axs.set_ylabel(label_y)
    axs.legend(fontsize=18)
    
def plot_2D(pc, comp_x, comp_y, axs, label_x, label_y):
    axs.scatter(pc[:,comp_x], pc[:,comp_y], s=15, alpha=0.2)
    axs.tick_params(axis='y', which='major', rotation=45)
    axs.grid(True)
    axs.set_xlabel(label_x)
    axs.set_ylabel(label_y)

figsize1 = 30
figsize2 = 5
fig, axs = plt.subplots(1, 6, figsize=(figsize1,figsize2))

for i in range(6):
    plot_2D_GTandRec(pointcloud_tensor, pred_pointcloud,
                     comp_x=i, comp_y=i+3, axs=axs[i],
                     label_x=labels_x[i], label_y=labels_y[i])
    
figsize1 = 30
figsize2 = 5
fig, axs = plt.subplots(1, 6, figsize=(figsize1,figsize2))
for i in range(6):
    plot_2D(pointcloud_tensor, comp_x=i, comp_y=i+3, axs=axs[i], label_x=labels_x[i], label_y=labels_y[i])

figsize1 = 30
figsize2 = 5
fig, axs = plt.subplots(1, 6, figsize=(figsize1,figsize2))
for i in range(6):
    plot_2D(pred_pointcloud, comp_x=i, comp_y=i+3, axs=axs[i], label_x=labels_x[i], label_y=labels_y[i])
    
figsize1 = 30
figsize2 = 10
#labels = label_x+labels_y
fig, axs = plt.subplots(3, 3, figsize=(figsize1,figsize2))
for i in range(3):
    plot_hist(pointcloud_tensor, pred_pointcloud, comp_x=i, axs=axs[0,i], label_x=labels_x[i])
for i in range(3):
    plot_hist(pointcloud_tensor, pred_pointcloud, comp_x=i+3, axs=axs[1,i], label_x=labels_y[i])
    
for i in range(3):
    plot_hist(pointcloud_tensor, pred_pointcloud, comp_x=i+6, axs=axs[2,i], label_x=labels_y[i+3])

# %%
def plot_per_slice(pc, slice_along, num_slices, comp_of_interest, axs, label='Number of particles'):
    if comp_of_interest is not None:
        comp_of_interest = comp_of_interest - 1

    slices = [np.min(pc[:, slice_along]) + (np.max(pc[:, slice_along]) - np.min(pc[:, slice_along])) * i/num_slices for i in range(num_slices)]
    pc_ = np.concatenate((pc, np.zeros((pc.shape[0], 1))), axis=1)

    for ind in range(len(slices)-1):
        pc_[:, -1][(pc_[:, slice_along]>=slices[ind]) & (pc_[:, slice_along]<=slices[ind+1])] = ind
    pc_[:, -1][(pc_[:, slice_along]>=slices[-1])] = len(slices) - 1

    if comp_of_interest is not None:
        mean_energy = [np.mean(pc_[:, comp_of_interest][pc_[:,-1]==ind]) if (pc_[:, comp_of_interest][pc_[:,-1]==ind]).shape[0] > 1 else None for ind in range(len(slices))]
        #std_energy = [np.std(pc_[:, comp_of_interest][pc_[:,-1]==ind]) if pc_[:, comp_of_interest][pc_[:,-1]==ind].shape[0] > 1 else None for ind in range(len(slices)) ]
        axs.plot([slice_ for slice_ in slices], mean_energy)
        axs.tick_params(axis='y', which='major', rotation=45)
        axs.grid(True)
        axs.set_xlabel('Z')
        axs.set_ylabel(label)
        #axs.legend(prop={'size': 20})

    if comp_of_interest == None:
        num_particles = [pc_[pc_[:,-1]==ind].shape[0] for ind in range(len(slices))]
        axs.plot([slice_ for slice_ in slices], num_particles)
        axs.tick_params(axis='y', which='major', rotation=45)
        axs.grid(True)
        axs.set_xlabel('Z')
        axs.set_ylabel(label)
        #axs.legend(prop={'size': 20})

def plot_per_slice_GTandRec(pc, pc_pred, slice_along, num_slices, comp_of_interest, axs, label='Number of particles'):
    if pc_pred is not None:
        slices_pred = [np.min(pc_pred[:, slice_along]) + (np.max(pc_pred[:, slice_along]) - np.min(pc_pred[:, slice_along])) * i/num_slices for i in range(num_slices)]
        pc_pred_ = np.concatenate((pc_pred, np.zeros((pc_pred.shape[0], 1))), axis=1)

        for ind in range(len(slices_pred)-1):
            pc_pred_[:, -1][(pc_pred_[:, -3]>=slices_pred[ind]) & (pc_pred_[:, -3]<=slices_pred[ind+1])] = ind
        pc_pred_[:, -1][(pc_pred_[:, -3]>=slices_pred[-1])] = len(slices_pred) - 1
    
    if comp_of_interest is not None:
        comp_of_interest = comp_of_interest - 1

    slices = [np.min(pc[:, slice_along]) + (np.max(pc[:, slice_along]) - np.min(pc[:, slice_along])) * i/num_slices for i in range(num_slices)]
    pc_ = np.concatenate((pc, np.zeros((pc.shape[0], 1))), axis=1)

    for ind in range(len(slices)-1):
        pc_[:, -1][(pc_[:, slice_along]>=slices[ind]) & (pc_[:, slice_along]<=slices[ind+1])] = ind
    pc_[:, -1][(pc_[:, slice_along]>=slices[-1])] = len(slices) - 1

    if comp_of_interest is not None:
        mean_energy = [np.mean(pc_[:, comp_of_interest][pc_[:,-1]==ind]) if (pc_[:, comp_of_interest][pc_[:,-1]==ind]).shape[0] > 1 else None for ind in range(len(slices))]
        std_energy = [np.std(pc_[:, comp_of_interest][pc_[:,-1]==ind]) if pc_[:, comp_of_interest][pc_[:,-1]==ind].shape[0] > 1 else None for ind in range(len(slices)) ]

        #axs.plot([slice_ for slice_ in slices], mean_energy, label="Groundtruth")
        if pc_pred is not None:
            print('plot pred', slices_pred)
            mean_energy_pred = [np.mean(pc_pred_[:, comp_of_interest+1][pc_pred_[:,-1]==ind]) if (pc_pred_[:, comp_of_interest+1][pc_pred_[:,-1]==ind]).shape[0] > 1 else None for ind in range(len(slices_pred))]
            std_energy_pred = [np.std(pc_pred_[:, comp_of_interest+1][pc_pred_[:,-1]==ind]) if pc_pred_[:, comp_of_interest+1][pc_pred_[:,-1]==ind].shape[0] > 1 else None for ind in range(len(slices_pred)) ]
            axs.plot([slice_ for slice_ in slices_pred], mean_energy_pred, label="Reconstruction")
            
        axs.tick_params(axis='y', which='major', rotation=45)
        axs.grid(True)
        axs.set_xlabel('Z')
        axs.set_ylabel(label)
        axs.legend(prop={'size': 20})


    if comp_of_interest == None:
        num_particles = [pc_[pc_[:,-1]==ind].shape[0] for ind in range(len(slices))]
        axs.plot([slice_ for slice_ in slices], num_particles)
        if pc_pred is not None:
            num_particles_pred = [pc_pred_[pc_pred_[:,-1]==ind].shape[0] for ind in range(len(slices_pred))]
            axs.plot([slice_ for slice_ in slices_pred], num_particles_pred)
        axs.tick_params(axis='y', which='major', rotation=45)
        axs.grid(True)
        axs.set_xlabel('Z')
        axs.set_ylabel(label)
        #axs.legend(prop={'size': 20})

# %%
slice_along = 2 #z: 2
num_slices = 100
comp_of_interest = -3
figsize1 = 35
figsize2 = 5

fig, axs = plt.subplots(1, 2, figsize=(figsize1,figsize2))
plot_per_slice_GTandRec(pointcloud_tensor, pred_pointcloud,
                        slice_along, num_slices, comp_of_interest,
                        axs[0], label='Number of particles')

plot_per_slice(pred_pointcloud, slice_along, num_slices, comp_of_interest, axs[1], label='Number of particles')

#for i in range(1,4,1):
#    visualizations.plot_per_slice_GTandRec(pointcloud_tensor, pred_pointcloud,
#                        slice_along, num_slices, comp_of_interest=-1*i,
#                        axs=axs[i], label='Mean ' + labels_y[-1*i])
# Out:
# plot pred [202.56365966796875, 202.63222579956056, 202.70079193115234, 202.76935806274415, 202.83792419433593, 202.90649032592773, 202.97505645751954, 203.04362258911132, 203.11218872070313, 203.1807548522949, 203.24932098388672, 203.31788711547853, 203.3864532470703, 203.45501937866212, 203.5235855102539, 203.5921516418457, 203.6607177734375, 203.7292839050293, 203.7978500366211, 203.86641616821288, 203.9349822998047, 204.0035484313965, 204.07211456298828, 204.14068069458008, 204.20924682617186, 204.27781295776367, 204.34637908935548, 204.41494522094726, 204.48351135253907, 204.55207748413085, 204.62064361572266, 204.68920974731446, 204.75777587890624, 204.82634201049805, 204.89490814208983, 204.96347427368164, 205.03204040527345, 205.10060653686523, 205.16917266845704, 205.23773880004882, 205.30630493164062, 205.37487106323243, 205.4434371948242, 205.51200332641602, 205.5805694580078, 205.6491355895996, 205.71770172119142, 205.7862678527832, 205.854833984375, 205.92340011596679, 205.9919662475586, 206.0605323791504, 206.12909851074218, 206.197664642334, 206.26623077392577, 206.33479690551758, 206.4033630371094, 206.47192916870117, 206.54049530029297, 206.60906143188475, 206.67762756347656, 206.74619369506837, 206.81475982666015, 206.88332595825196, 206.95189208984374, 207.02045822143555, 207.08902435302736, 207.15759048461913, 207.22615661621094, 207.29472274780272, 207.36328887939453, 207.43185501098634, 207.50042114257812, 207.56898727416993, 207.6375534057617, 207.70611953735352, 207.77468566894532, 207.8432518005371, 207.9118179321289, 207.9803840637207, 208.0489501953125, 208.1175163269043, 208.1860824584961, 208.2546485900879, 208.32321472167968, 208.39178085327148, 208.4603469848633, 208.52891311645507, 208.59747924804688, 208.66604537963866, 208.73461151123047, 208.80317764282228, 208.87174377441406, 208.94030990600587, 209.00887603759764, 209.07744216918945, 209.14600830078126, 209.21457443237304, 209.28314056396485, 209.35170669555663]
